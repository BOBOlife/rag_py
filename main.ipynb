# %%
from typing import List

def split_into_chunks(doc_file: str) -> List[str]:
    with open(doc_file, 'r') as file:
        content = file.read()
    return [chunk for chunk in content.split("\n\n")]

chunks = split_into_chunks("doc.md")

for i, chunk in enumerate(chunks):
    print(f"[{i}]  {chunk}\n")
# Out:
# [0]  # 迪迦奥特曼与戴拿奥特曼的离谱冒险
#
# [1]  一天，地球防卫队警报响起，但这次不是因为毁灭性入侵，而是一只叫"懒洋洋"的粉色毛绒兔子怪兽在市中心广场上睡着了，肚皮上还写着"请勿打扰，正在减肥中"。迪迦奥特曼赶到现场摆出战斗姿势，却被懒洋洋的呼噜声搞得不知所措。
#
# [2]  戴拿奥特曼随后赶到，看到这场景笑出了声："哈哈哈，迪迦，这是什么情况？怪兽也开始养生了？"懒洋洋慢悠悠地睁开眼睛解释说它是来地球参加减肥训练营的，因为怪兽星球肥胖率太高了。
#
# [3]  在懒洋洋的软磨硬泡下，迪迦和戴拿竟然真的带它去了健身房，还把它缩小到人类大小。但懒洋洋一站上跑步机，机器就冒烟了；举重时把杠铃掰弯；试动感单车时把座椅坐塌，整个健身房十分钟内变成废墟。
#
# [4]  就在这时，邪恶怪兽"破坏王"突然出现，看到懒洋洋在"破坏"健身房，以为这是新的破坏方式，也跟着开始疯狂破坏建筑。迪迦和戴拿准备战斗，但懒洋洋拦住了他们："让我来！这个破坏王抢了我的风头！"
#
# [5]  懒洋洋冲向破坏王，用肚皮去撞它，还一边撞一边喊："看我的无敌肚皮攻击！"接着使出"呼噜声波攻击"和"懒散翻滚"等奇葩招式，把破坏王搞得晕头转向。迪迦和戴拿在一旁看得目瞪口呆。
#
# [6]  最终，懒洋洋使出终极绝招"减肥决心光波"，这道粉色光束没有破坏力，但充满了正能量。破坏王被击中后突然感动："原来减肥是这么伟大的事情！我也想减肥！"说着也加入了减肥大军。
#
# [7]  迪迦和戴拿彻底无语了，战斗居然变成了减肥动员大会。从此，两只怪兽一起报名参加地球减肥训练营，迪迦和戴拿成了它们的专属教练。
#
# [8]  每天早上，人们都能看到奇特的一幕：两只巨大怪兽在公园做早操，迪迦喊口令，戴拿示范动作。懒洋洋和破坏王虽然经常偷懒，但总体上很努力。
#
# [9]  三个月后，它们真的瘦了一圈，还获得了"最佳减肥学员"奖状。从此，地球上的怪兽们都知道了，想要变强不一定非要破坏，减肥也是很有前途的选择。
#
# [10]  迪迦和戴拿多了一个新身份——宇宙减肥推广大使。当怪兽们都忙着减肥的时候，谁还有时间搞破坏呢？这大概就是史上最离谱但也最有效的和平方案了吧！

# %%
from sentence_transformers import SentenceTransformer

embedding_model = SentenceTransformer("shibing624/text2vec-base-chinese")
def embed_chunk(chunk: str) -> List[float]:
    embedding = embedding_model.encode(chunk)
    return embedding.tolist()

test_embedding  = embed_chunk("测试内容")
print(len(test_embedding))
print(test_embedding)
# Out:
# 768
007, 0.6190857887268066, -1.1394072771072388, -0.4798457622528076, -0.15315528213977814, 0.21498320996761322, -0.7394565939903259, 0.8001604676246643, -0.5439147353172302, -0.42557644844055176, -0.00424731383100152, -0.38800308108329773, -1.266358733177185, 0.15544359385967255, -0.25219690799713135, -0.10385047644376755, 0.337618887424469, 0.16339077055454254, 1.0740127563476562, 0.35062453150749207, -0.7608919143676758, -0.09212975203990936, 1.1833281517028809, -0.6568901538848877, -0.2256670445203781, 0.24159035086631775, -0.25851213932037354, 0.3891989290714264, 0.09365636110305786, 0.13960660994052887, 0.2607309818267822, 0.24355067312717438, -0.910333514213562, -0.09451274573802948, 0.4349355101585388, 0.19402991235256195, 0.39844709634780884, 0.10897372663021088, 0.09740529954433441, -0.3404897153377533, -0.6446160674095154, 0.016312656924128532, -0.21992816030979156, 0.37621864676475525, -0.8344111442565918, 0.665 ...

# %%
import chromadb

chromadb_client = chromadb.EphemeralClient()
chromadb_collection = chromadb_client.get_or_create_collection(name="default")

def save_embeddings(chunks: List[str], embeddings: List[List[float]]) -> None:
    ids = [str(i) for i in range(len(chunks))]
    chromadb_collection.add(
        documents = chunks,
        embeddings = embeddings,
        ids = ids
    )

save_embeddings(chunks, embeddings)

# %%
def retrieve(query:str, top_k: int) -> List[str]:
    query_embedding = embed_chunk(query)
    results = chromadb_collection.query(
        query_embeddings = [query_embedding],
        n_results = top_k
    )
    return results['documents'][0]

query="怪兽想干什么？"

retrieved_chunks = retrieve(query,5)

for i, chunk in enumerate(retrieved_chunks):
    print(f"[{i}] {chunk}\n")
# Out:
# [0] ## 第一章：怪兽的奇葩计划
#
# [1] 懒洋洋怪兽慢吞吞地坐起来，揉了揉眼睛："你们这些奥特曼，整天就知道打打杀杀，能不能有点新意？本怪兽这次来地球是有正事的。"
#
# [2] 就在这时，戴拿奥特曼也飞到了现场，看到这情况直接笑出了声："哈哈哈，迪迦，这是什么情况？怪兽也开始养生了？"
#
# [3] 从此以后，地球上的怪兽们都知道了，想要变强不一定非要破坏，减肥也是一种很有前途的选择。
#
# [4] 迪迦奥特曼第一时间赶到现场，摆出了经典的战斗姿势，但看到这一幕也愣住了。"喂！你这只怪兽，快起来战斗！"迪迦大喊道。

# %%
from sentence_transformers import CrossEncoder

def rerank(query: str, retrieved_chunks: List[str], top_k: int) -> List[str]:
    cross_encoder = CrossEncoder('cross-encoder/mmarco-mMiniLMv2-L12-H384-v1')
    pairs = [(query, chunk) for chunk in retrieved_chunks]
    scores = cross_encoder.predict(pairs)
    chunk_with_score_list = [(chunk, score) 
                             for chunk, score in zip(retrieved_chunks, scores)]
    chunk_with_score_list.sort(key=lambda pair: pair[1], reverse= True)

    return [chunk for chunk,  _ in chunk_with_score_list][:top_k]

reranked_chunks = rerank(query,retrieved_chunks, 3)

for i , chunk in enumerate(reranked_chunks):
    print(f"[{i}] {chunk}\n")
# Out:
# [0] 从此以后，地球上的怪兽们都知道了，想要变强不一定非要破坏，减肥也是一种很有前途的选择。
#
# [1] 懒洋洋怪兽慢吞吞地坐起来，揉了揉眼睛："你们这些奥特曼，整天就知道打打杀杀，能不能有点新意？本怪兽这次来地球是有正事的。"
#
# [2] ## 第一章：怪兽的奇葩计划
